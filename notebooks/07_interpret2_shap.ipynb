# %% [markdown]
# # Interpretability 2, from Local to Global explanations with SHAP — SHapley Additive exPlanations
# ## Local explanations: explaining one prediction
# SHAP explains the prediction for a *single* input sample \(x\) by decomposing the model output into **feature contributions**:
#
# \begin{equation}
# f(x) = \phi_0 + \sum_{i=1}^{M}\phi_i
# \end{equation}
#
# Where:
# -$f(x)$ is the model output (e.g. probability of class 1)
# - $\phi_0$ is the **baseline** prediction (expected model output over a reference dataset)
# - $\phi_i$ is the **contribution** of feature $i$ for this specific sample
#
# Interpretation:
# - $\phi_i > 0$: feature $i$ pushes the prediction **up**
# - $\phi_i < 0$: feature $i$ pushes the prediction **down**
# - the contributions sum exactly to the prediction (**additivity**)
#
# ## Why Shapley values?
# SHAP is based on **Shapley values** from cooperative game theory.
#
# Each feature as a “player” in a game, and the prediction \(f(x)\) as the “payout”.
# Shapley

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.12/dist-packages (0.50.0)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from shap) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from shap) (1.16.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.12/dist-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.12/dist-packages (from shap) (25.0)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.12/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from shap) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from shap) (4.15.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->shap) (2025.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->shap) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)

# %%
# If needed, install dependencies
# !pip install shap
import numpy as np
import pandas as pd
import shap
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},l=Symbol.for("react.portal"),u=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:l,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=u.T,n=o.p;try{if(u.T=null,o.p=2,e)return e()}finally{u.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return u.H.useFormState(e,t,n)},t.useFormStatus=function(){return u.H.useHostTransitionStatus()},t.version="19.2.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function l(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function u(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...

# %% [markdown]
# # 03 — CMB-inspired ML Example: Classifying Power Spectra

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    roc_auc_score,
)

rng = np.random.default_rng(42)

plt.rcParams["figure.figsize"] = (7, 5)
plt.rcParams["axes.grid"] = True

# %%
# Multipole grid
ell_min, ell_max = 2, 2000
ells = np.arange(ell_min, ell_max + 1)

len(ells)
# Out:
# 1999

# %%
def baseline_cl(ell, A=1.0, l_peak=220.0, width_peak=80.0, damping_scale=1500.0):
    """
    Toy 'CMB-like' angular power spectrum:
    - broad acoustic peak
    - decaying tail
    """
    # Broad first peak
    peak = np.exp(-0.5 * ((ell - l_peak) / width_peak) ** 2)
    # Some gentle wiggles (very crude multi-peak feel)
    wiggles = 0.4 * np.cos(ell / 150.0) + 0.6
    # Damping at high ell
    damping = np.exp(-(ell / damping_scale) ** 2)
    cl = A * peak * wiggles * damping
    # Avoid zeros
    return cl + 1e-8

cl_base = baseline_cl(ells)
plt.plot(ells, cl_base)
plt.xlabel(r"$\ell$")
plt.ylabel(r"$C_\ell$  (arb. units, toy)")
plt.title("Toy 'CMB-like' baseline spectrum")
plt.show()

# %%
def add_local_feature(cl, ell, amp=0.25, l0=500.0, width=80.0, freq=0.15):
    """
    Multiply baseline Cl by a localized oscillatory feature around ell ~ l0.

    cl_new = cl * (1 + amp * bump),
    where bump is a Gaussian envelope times a sinusoid in ell.
    """
    envelope = np.exp(-0.5 * ((ell - l0) / width) ** 2)
    oscill = np.sin(freq * (ell - l0))
    bump = envelope * oscill
    return cl * (1.0 + amp * bump)

cl_feat = add_local_feature(cl_base, ells, amp=0.3, l0=500.0, width=70.0, freq=0.18)

# %%
def bin_cl(ell, cl, nbins=50):
    """
    Bin C_ell into nbins approximately equal in ell.
    Returns bandpower centers and averaged C_ell in each bin.
    """
    indices = np.array_split(np.arange(len(ell)), nbins)
    cl_binned = np.array([cl[idx].mean() for idx in indices])
    ell_centers = np.array([ell[idx].mean() for idx in indices])
    return ell_centers, cl_binned

def noisy_bandpower_realization(ell, cl_theory, frac_noise=0.1, nbins=50):
    """
    From a theoretical spectrum, create a noisy binned spectrum.
    frac_noise is a fractional Gaussian noise level.
    """
    ell_c, cl_b = bin_cl(ell, cl_theory, nbins=nbins)
    noise = rng.normal(0.0, frac_noise * cl_b)
    cl_obs = cl_b + noise
    # Ensure positivity
    cl_obs = np.clip(cl_obs, 1e-8, None)
    return ell_c, cl_obs

# Quick test
ell_c_test, cl_obs_test = noisy_bandpower_realization(ells, cl_base, frac_noise=0.15)
plt.errorbar(ell_c_test, cl_obs_test, yerr=0.15*cl_obs_test, fmt="o", ms=4)
plt.xlabel(r"binned $\ell$")
plt.ylabel(r"binned $C_\ell$")
plt.title("Example noisy bandpowers (toy)")
plt.show()

# %%
N = 2000             #total number of spectra
nbins = 150           #bandpowers per spectrum
frac_noise = 0.02    #fractional noise level

X = []
y = []
ell_centers = None

for i in range(N):
    #Randomize some baseline parameters slightly
    A = rng.uniform(0.9, 1.1)
    l_peak = rng.uniform(200.0, 240.0)
    width_peak = rng.uniform(60.0, 100.0)
    damping = rng.uniform(1300.0, 1800.0)

    cl0 = baseline_cl(ells, A=A, l_peak=l_peak,
                      width_peak=width_peak, damping_scale=damping)

    if rng.random() < 0.5:
        #Class 0: "ΛCDM-like" (no extra feature)
        cl_theory = cl0
        label = 0
    else:
        #Class 1: baseline + feature with random location & amplitude
        amp = rng.uniform(0.6, 1.2)
        l0_feat = rng.normal(600.0, 30.0)     # concentrated around ~600
        width_feat = rng.uniform(50.0, 80.0)
        freq_feat = rng.uniform(0.14, 0.20)
        cl_featured = add_local_feature(
            cl0, ells,
            amp=amp, l0=l0_feat,
            width=width_feat, freq=freq_feat
        )
        cl_theory = cl_featured
        label = 1

    ell_c, cl_obs = noisy_bandpower_realization(
        ells, cl_theory, frac_noise=frac_noise, nbins=nbins
    )
    if ell_centers is None:
        ell_centers = ell_c  # store once

    X.append(cl_obs)
    y.append(label)

X = np.array(X)
y = np.array(y)

# %%
def plot_example_spectra(X, y, ell_c, n_per_class=3):
    plt.figure(figsize=(7, 5))
    classes = [0, 1]
    labels = ["ΛCDM-like (class 0)", "Feature model (class 1)"]
    markers = ["o", "s"]

    for cls, lab, mk in zip(classes, labels, markers):
        idx = np.where(y == cls)[0]
        idx = rng.choice(idx, size=min(n_per_class, 1), replace=False)
        for j in idx:
            plt.plot(ell_c, X[j], marker=mk, ms=4, alpha=0.7, label=lab if j == idx[0] else None)

    plt.xlabel(r"binned multipole $\ell$")
    plt.ylabel(r"$C_\ell$ (binned, noisy, arb. units)")
    plt.title("Example spectra from each class")
    plt.legend()
    plt.show()

plot_example_spectra(X, y, ell_centers)

# %%
import numpy as np
rng = np.random.default_rng(0)

ells = np.arange(2, 2000)

def baseline_cl(ells, A=1.0, ns=0.965):
    ell0 = 80.0
    cl = A * (ells / ell0) ** (ns - 1.0) * np.exp(-(ells / 1800.0) ** 2)
    return cl

def add_feature_simple(cl, ells, amp=0.05, ell_min=300, ell_max=700):
    """Very simple feature: boost power by (1+amp) in a contiguous ell range."""
    cl_feat = cl.copy()
    mask = (ells >= ell_min) & (ells <= ell_max)
    cl_feat[mask] *= (1.0 + amp)
    return cl_feat

def noisy_bandpowers(cl, frac_noise=0.05, nbins=30):
    indices = np.array_split(np.arange(len(cl)), nbins)
    bp = np.array([cl[idx].mean() for idx in indices])
    bp = bp * (1.0 + rng.normal(0.0, frac_noise, size=bp.size))
    return bp

def generate_dataset(N=3000, nbins=50):
    X, y = [], []
    for i in range(N):
        cl_base = baseline_cl(ells, A=1.0, ns=0.965)

        if rng.random() < 0.5:
            #Class 0: pure baseline
            cl = cl_base
            label = 0
        else:
            #Class 1: baseline with a big fat bump between ell=300 and 700
            cl = add_feature_simple(cl_base, ells, amp=0.01,
                                    ell_min=300, ell_max=700)
            label = 1

        bp = noisy_bandpowers(cl, frac_noise=0.01, nbins=nbins)
        X.append(np.log(bp + 1e-6))
        y.append(label)

    return np.array(X), np.array(y)

X, y = generate_dataset()
print("X shape:", X.shape)
print("Class counts:", np.unique(y, return_counts=True))
# Out:
# X shape: (3000, 50)
# Class counts: (array([0, 1]), array([1525, 1475]))

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=45
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=45
)

X_train.shape, X_val.shape
# Out:
# ((1680, 50), (420, 50))

# %%
import tensorflow as tf
tf.keras.backend.clear_session()  #Clear previous models from memory

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

input_dim = X_train.shape[1]

def make_cmb_classifier():
    model = Sequential([
        Dense(64, activation="relu", input_shape=(input_dim,)),
        Dense(1, activation="sigmoid")  #binary classification
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    return model

model = make_cmb_classifier()
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         3,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,329 (13.00 KB)
#  Trainable params: 3,329 (13.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 200
batch_size = 32

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=epochs,
    batch_size=batch_size,
    verbose=1
)

print("Final training accuracy:", history.history["accuracy"][-1])
print("Final validation accuracy:", history.history["val_accuracy"][-1])
# Out:
# Epoch 1/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.5019 - loss: 0.6954 - val_accuracy: 0.5167 - val_loss: 0.6885
# Epoch 2/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5073 - loss: 0.6945 - val_accuracy: 0.4833 - val_loss: 0.6887
# Epoch 3/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5615 - loss: 0.6878 - val_accuracy: 0.4833 - val_loss: 0.6989
# Epoch 4/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5250 - loss: 0.6942 - val_accuracy: 0.4833 - val_loss: 0.6946
# Epoch 5/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5051 - loss: 0.6914 - val_accuracy: 0.4833 - val_loss: 0.6893
# Epoch 6/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5028 - loss: 0.6912 - val_accuracy: 0.5167 - val_loss: 0.6816
# Epoch 7/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5269 - loss: 0.6810 - val_accuracy: 0.4833 - val_loss: 0.6838
# Epoch 8/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5677 - loss: 0.6856 - val_accuracy: 0.5167 - val_loss: 0.6780
# Epoch 9/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5530 - loss: 0.6795 - val_accuracy: 0.5952 - val_loss: 0.6761
# Epoch 10/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7104 - loss: 0.6781 - val_accuracy: 0.6262 - val_loss: 0.6741
# Epoch 11/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5815 - loss: 0.6782 - val_accuracy: 0.6262 - val_loss: 0.6719
# Epoch 12/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5641 - loss: 0.6747 - val_accuracy: 0.8929 - val_loss: 0.6704
# Epoch 13/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6749 - loss: 0.6723 - val_accuracy: 0.7786 - val_loss: 0.6669
# Epoch 14/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6217 - loss: 0.6659 - val_accuracy: 0.5976 - val_loss: 0.6642
# Epoch 15/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5369 - loss: 0.6772 - val_accuracy: 0.4857 - val_loss: 0.6711
# Epoch 16/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6108 - loss: 0.6663 - val_accuracy: 0.6000 - val_loss: 0.6595
# Epoch 17/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6094 - loss: 0.6649 - val_accuracy: 0.8262 - val_loss: 0.6581
# Epoch 18/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8163 - loss: 0.6574 - val_accuracy: 0.4857 - val_loss: 0.6641
# Epoch 19/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6426 - loss: 0.6579 - val_accuracy: 0.4857 - val_loss: 0.6607
# Epoch 20/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5874 - loss: 0.6593 - val_accuracy: 0.6048 - val_loss: 0.6467
# Epoch 21/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6460 - loss: 0.6478 - val_accuracy: 0.8571 - val_loss: 0.6411
# Epoch 22/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7229 - loss: 0.6434 - val_accuracy: 0.9048 - val_loss: 0.6362
# Epoch 23/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7275 - loss: 0.6432 - val_accuracy: 0.5167 - val_loss: 0.6449
# Epoch 24/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7093 - loss: 0.6372 - val_accuracy: 0.9167 - val_loss: 0.6269
# Epoch 25/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7628 - loss: 0.6281 - val_accuracy: 0.9095 - val_loss: 0.6211
# Epoch 26/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7783 - loss: 0.6258 - val_accuracy: 0.8167 - val_loss: 0.6154
# Epoch 27/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8428 - loss: 0.6182 - val_accuracy: 0.5167 - val_loss: 0.6505
# Epoch 28/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6219 - loss: 0.6285 - val_accuracy: 0.7643 - val_loss: 0.6047
# Epoch 29/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8626 - loss: 0.6043 - val_accuracy: 0.8262 - val_loss: 0.6019
# Epoch 30/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8117 - loss: 0.5972 - val_accuracy: 0.5405 - val_loss: 0.6179
# Epoch 31/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7411 - loss: 0.6042 - val_accuracy: 0.9143 - val_loss: 0.5823
# Epoch 32/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8370 - loss: 0.5859 - val_accuracy: 0.7643 - val_loss: 0.5858
# Epoch 33/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6772 - loss: 0.5923 - val_accuracy: 0.7333 - val_loss: 0.5748
# Epoch 34/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7820 - loss: 0.5783 - val_accuracy: 0.7190 - val_loss: 0.5693
# Epoch 35/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8731 - loss: 0.5625 - val_accuracy: 0.9071 - val_loss: 0.5528
# Epoch 36/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7556 - loss: 0.5586 - val_accuracy: 0.9190 - val_loss: 0.5455
# Epoch 37/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8439 - loss: 0.5506 - val_accuracy: 0.7929 - val_loss: 0.5441
# Epoch 38/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8630 - loss: 0.5424 - val_accuracy: 0.8429 - val_loss: 0.5328
# Epoch 39/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8499 - loss: 0.5285 - val_accuracy: 0.6405 - val_loss: 0.5544
# Epoch 40/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8385 - loss: 0.5288 - val_accuracy: 0.9095 - val_loss: 0.5146
# Epoch 41/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8617 - loss: 0.5163 - val_accuracy: 0.6143 - val_loss: 0.5653
# Epoch 42/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7278 - loss: 0.5312 - val_accuracy: 0.9048 - val_loss: 0.5018
# Epoch 43/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8817 - loss: 0.4968 - val_accuracy: 0.9143 - val_loss: 0.4911
# Epoch 44/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9061 - loss: 0.4907 - val_accuracy: 0.9024 - val_loss: 0.4838
# Epoch 45/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8979 - loss: 0.4829 - val_accuracy: 0.9024 - val_loss: 0.4792
# Epoch 46/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8849 - loss: 0.4742 - val_accuracy: 0.8381 - val_loss: 0.4769
# Epoch 47/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8899 - loss: 0.4758 - val_accuracy: 0.8405 - val_loss: 0.4824
# Epoch 48/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8976 - loss: 0.4585 - val_accuracy: 0.8810 - val_loss: 0.4566
# Epoch 49/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8827 - loss: 0.4472 - val_accuracy: 0.9071 - val_loss: 0.4475
# Epoch 50/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8996 - loss: 0.4453 - val_accuracy: 0.8048 - val_loss: 0.4758
# Epoch 51/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8688 - loss: 0.4465 - val_accuracy: 0.9167 - val_loss: 0.4271
# Epoch 52/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8822 - loss: 0.4371 - val_accuracy: 0.8357 - val_loss: 0.4383
# Epoch 53/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9065 - loss: 0.4190 - val_accuracy: 0.9262 - val_loss: 0.4133
# Epoch 54/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9190 - loss: 0.4092 - val_accuracy: 0.9238 - val_loss: 0.4067
# Epoch 55/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9146 - loss: 0.4071 - val_accuracy: 0.8667 - val_loss: 0.4221
# Epoch 56/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8376 - loss: 0.4312 - val_accuracy: 0.8905 - val_loss: 0.4043
# Epoch 57/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8912 - loss: 0.4052 - val_accuracy: 0.9262 - val_loss: 0.3877
# Epoch 58/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9283 - loss: 0.3840 - val_accuracy: 0.9238 - val_loss: 0.3822
# Epoch 59/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9164 - loss: 0.3807 - val_accuracy: 0.9071 - val_loss: 0.3804
# Epoch 60/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8575 - loss: 0.4044 - val_accuracy: 0.8690 - val_loss: 0.3931
# Epoch 61/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8934 - loss: 0.3786 - val_accuracy: 0.9190 - val_loss: 0.3672
# Epoch 62/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8667 - loss: 0.4010 - val_accuracy: 0.8786 - val_loss: 0.3801
# Epoch 63/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9116 - loss: 0.3583 - val_accuracy: 0.9119 - val_loss: 0.3636
# Epoch 64/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8872 - loss: 0.3689 - val_accuracy: 0.9310 - val_loss: 0.3511
# Epoch 65/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9221 - loss: 0.3508 - val_accuracy: 0.9262 - val_loss: 0.3457
# Epoch 66/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9036 - loss: 0.3582 - val_accuracy: 0.9214 - val_loss: 0.3423
# Epoch 67/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9346 - loss: 0.3355 - val_accuracy: 0.8762 - val_loss: 0.3630
# Epoch 68/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8862 - loss: 0.3548 - val_accuracy: 0.9095 - val_loss: 0.3379
# Epoch 69/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9186 - loss: 0.3368 - val_accuracy: 0.8738 - val_loss: 0.3520
# Epoch 70/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8937 - loss: 0.3496 - val_accuracy: 0.9024 - val_loss: 0.3346
# Epoch 71/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9164 - loss: 0.3360 - val_accuracy: 0.9286 - val_loss: 0.3195
# Epoch 72/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8888 - loss: 0.3391 - val_accuracy: 0.8643 - val_loss: 0.3501
# Epoch 73/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8904 - loss: 0.3331 - val_accuracy: 0.9095 - val_loss: 0.3198
# Epoch 74/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9255 - loss: 0.3148 - val_accuracy: 0.9286 - val_loss: 0.3082
# Epoch 75/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9234 - loss: 0.3099 - val_accuracy: 0.9310 - val_loss: 0.3053
# Epoch 76/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9041 - loss: 0.3189 - val_accuracy: 0.9119 - val_loss: 0.3136
# Epoch 77/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9318 - loss: 0.3011 - val_accuracy: 0.9286 - val_loss: 0.2977
# Epoch 78/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9154 - loss: 0.3057 - val_accuracy: 0.9167 - val_loss: 0.3001
# Epoch 79/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9186 - loss: 0.2929 - val_accuracy: 0.9214 - val_loss: 0.2955
# Epoch 80/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9029 - loss: 0.2984 - val_accuracy: 0.9167 - val_loss: 0.2932
# Epoch 81/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8975 - loss: 0.3109 - val_accuracy: 0.9310 - val_loss: 0.2863
# Epoch 82/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9172 - loss: 0.2841 - val_accuracy: 0.9143 - val_loss: 0.2900
# Epoch 83/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9126 - loss: 0.2897 - val_accuracy: 0.9143 - val_loss: 0.2878
# Epoch 84/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9115 - loss: 0.2887 - val_accuracy: 0.9238 - val_loss: 0.2805
# Epoch 85/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8980 - loss: 0.2919 - val_accuracy: 0.9167 - val_loss: 0.2809
# Epoch 86/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9269 - loss: 0.2828 - val_accuracy: 0.9167 - val_loss: 0.2880
# Epoch 87/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9111 - loss: 0.2774 - val_accuracy: 0.9119 - val_loss: 0.2745
# Epoch 88/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9247 - loss: 0.2682 - val_accuracy: 0.9262 - val_loss: 0.2707
# Epoch 89/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9050 - loss: 0.2756 - val_accuracy: 0.9048 - val_loss: 0.2839
# Epoch 90/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9167 - loss: 0.2806 - val_accuracy: 0.9143 - val_loss: 0.2750
# Epoch 91/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9131 - loss: 0.2748 - val_accuracy: 0.9310 - val_loss: 0.2610
# Epoch 92/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8992 - loss: 0.2802 - val_accuracy: 0.9310 - val_loss: 0.2596
# Epoch 93/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9355 - loss: 0.2491 - val_accuracy: 0.9333 - val_loss: 0.2587
# Epoch 94/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9109 - loss: 0.2686 - val_accuracy: 0.9310 - val_loss: 0.2555
# Epoch 95/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9151 - loss: 0.2593 - val_accuracy: 0.9071 - val_loss: 0.2721
# Epoch 96/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9193 - loss: 0.2561 - val_accuracy: 0.9143 - val_loss: 0.2606
# Epoch 97/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9221 - loss: 0.2608 - val_accuracy: 0.9190 - val_loss: 0.2649
# Epoch 98/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8990 - loss: 0.2753 - val_accuracy: 0.9167 - val_loss: 0.2673
# Epoch 99/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9118 - loss: 0.2619 - val_accuracy: 0.8762 - val_loss: 0.2866
# Epoch 100/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9187 - loss: 0.2544 - val_accuracy: 0.9333 - val_loss: 0.2438
# Epoch 101/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9281 - loss: 0.2389 - val_accuracy: 0.9167 - val_loss: 0.2499
# Epoch 102/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9026 - loss: 0.2596 - val_accuracy: 0.9071 - val_loss: 0.2616
# Epoch 103/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9319 - loss: 0.2370 - val_accuracy: 0.9262 - val_loss: 0.2406
# Epoch 104/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9251 - loss: 0.2372 - val_accuracy: 0.9143 - val_loss: 0.2503
# Epoch 105/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9299 - loss: 0.2310 - val_accuracy: 0.9405 - val_loss: 0.2360
# Epoch 106/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9288 - loss: 0.2331 - val_accuracy: 0.9048 - val_loss: 0.2592
# Epoch 107/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9181 - loss: 0.2402 - val_accuracy: 0.8881 - val_loss: 0.2697
# Epoch 108/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9171 - loss: 0.2338 - val_accuracy: 0.8714 - val_loss: 0.2868
# Epoch 109/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9076 - loss: 0.2516 - val_accuracy: 0.9190 - val_loss: 0.2470
# Epoch 110/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9131 - loss: 0.2434 - val_accuracy: 0.9262 - val_loss: 0.2312
# Epoch 111/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9251 - loss: 0.2320 - val_accuracy: 0.9143 - val_loss: 0.2350
# Epoch 112/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9148 - loss: 0.2374 - val_accuracy: 0.8905 - val_loss: 0.2626
# Epoch 113/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9202 - loss: 0.2536 - val_accuracy: 0.9167 - val_loss: 0.2457
# Epoch 114/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9072 - loss: 0.2496 - val_accuracy: 0.9333 - val_loss: 0.2245
# Epoch 115/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9241 - loss: 0.2411 - val_accuracy: 0.9333 - val_loss: 0.2238
# Epoch 116/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8958 - loss: 0.2559 - val_accuracy: 0.9238 - val_loss: 0.2252
# Epoch 117/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9231 - loss: 0.2202 - val_accuracy: 0.9190 - val_loss: 0.2378
# Epoch 118/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9087 - loss: 0.2435 - val_accuracy: 0.9000 - val_loss: 0.2508
# Epoch 119/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9026 - loss: 0.2456 - val_accuracy: 0.9167 - val_loss: 0.2390
# Epoch 120/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9264 - loss: 0.2151 - val_accuracy: 0.9357 - val_loss: 0.2185
# Epoch 121/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9045 - loss: 0.2413 - val_accuracy: 0.8690 - val_loss: 0.2933
# Epoch 122/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9162 - loss: 0.2366 - val_accuracy: 0.9167 - val_loss: 0.2217
# Epoch 123/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9282 - loss: 0.2232 - val_accuracy: 0.9381 - val_loss: 0.2155
# Epoch 124/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9189 - loss: 0.2296 - val_accuracy: 0.8286 - val_loss: 0.3732
# Epoch 125/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8959 - loss: 0.2598 - val_accuracy: 0.9333 - val_loss: 0.2142
# Epoch 126/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9117 - loss: 0.2376 - val_accuracy: 0.9405 - val_loss: 0.2128
# Epoch 127/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9221 - loss: 0.2168 - val_accuracy: 0.9238 - val_loss: 0.2148
# Epoch 128/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9134 - loss: 0.2134 - val_accuracy: 0.9333 - val_loss: 0.2137
# Epoch 129/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9187 - loss: 0.2223 - val_accuracy: 0.9405 - val_loss: 0.2104
# Epoch 130/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9268 - loss: 0.2117 - val_accuracy: 0.8643 - val_loss: 0.2851
# Epoch 131/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9087 - loss: 0.2330 - val_accuracy: 0.9405 - val_loss: 0.2092
# Epoch 132/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9336 - loss: 0.2041 - val_accuracy: 0.9119 - val_loss: 0.2279
# Epoch 133/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9152 - loss: 0.2214 - val_accuracy: 0.9262 - val_loss: 0.2099
# Epoch 134/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9037 - loss: 0.2330 - val_accuracy: 0.9357 - val_loss: 0.2073
# Epoch 135/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9161 - loss: 0.2230 - val_accuracy: 0.9143 - val_loss: 0.2192
# Epoch 136/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9084 - loss: 0.2265 - val_accuracy: 0.9405 - val_loss: 0.2054
# Epoch 137/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9301 - loss: 0.2054 - val_accuracy: 0.9310 - val_loss: 0.2063
# Epoch 138/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9389 - loss: 0.2094 - val_accuracy: 0.9167 - val_loss: 0.2231
# Epoch 139/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9423 - loss: 0.1838 - val_accuracy: 0.9238 - val_loss: 0.2184
# Epoch 140/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9331 - loss: 0.2070 - val_accuracy: 0.9167 - val_loss: 0.2334
# Epoch 141/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9169 - loss: 0.2220 - val_accuracy: 0.8833 - val_loss: 0.2543
# Epoch 142/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9140 - loss: 0.2246 - val_accuracy: 0.9143 - val_loss: 0.2156
# Epoch 143/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9205 - loss: 0.2107 - val_accuracy: 0.8738 - val_loss: 0.2624
# Epoch 144/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9125 - loss: 0.2184 - val_accuracy: 0.9214 - val_loss: 0.2093
# Epoch 145/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9256 - loss: 0.2134 - val_accuracy: 0.9048 - val_loss: 0.2374
# Epoch 146/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9211 - loss: 0.2032 - val_accuracy: 0.9238 - val_loss: 0.2035
# Epoch 147/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9309 - loss: 0.1980 - val_accuracy: 0.9167 - val_loss: 0.2081
# Epoch 148/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9127 - loss: 0.2125 - val_accuracy: 0.9310 - val_loss: 0.2037
# Epoch 149/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9134 - loss: 0.2147 - val_accuracy: 0.9381 - val_loss: 0.1981
# Epoch 150/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9226 - loss: 0.1979 - val_accuracy: 0.9143 - val_loss: 0.2123
# Epoch 151/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9295 - loss: 0.2011 - val_accuracy: 0.9286 - val_loss: 0.1989
# Epoch 152/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9168 - loss: 0.2129 - val_accuracy: 0.9214 - val_loss: 0.2046
# Epoch 153/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9163 - loss: 0.2045 - val_accuracy: 0.9381 - val_loss: 0.1957
# Epoch 154/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9364 - loss: 0.1903 - val_accuracy: 0.9381 - val_loss: 0.1960
# Epoch 155/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9167 - loss: 0.2072 - val_accuracy: 0.9095 - val_loss: 0.2329
# Epoch 156/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9306 - loss: 0.1954 - val_accuracy: 0.9429 - val_loss: 0.1946
# Epoch 157/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9321 - loss: 0.1902 - val_accuracy: 0.9381 - val_loss: 0.1936
# Epoch 158/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9225 - loss: 0.2001 - val_accuracy: 0.9286 - val_loss: 0.1948
# Epoch 159/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9305 - loss: 0.1911 - val_accuracy: 0.9310 - val_loss: 0.1938
# Epoch 160/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9185 - loss: 0.2032 - val_accuracy: 0.9214 - val_loss: 0.2064
# Epoch 161/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9361 - loss: 0.1907 - val_accuracy: 0.8810 - val_loss: 0.2565
# Epoch 162/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9065 - loss: 0.2250 - val_accuracy: 0.9286 - val_loss: 0.1999
# Epoch 163/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9290 - loss: 0.1882 - val_accuracy: 0.9167 - val_loss: 0.2227
# Epoch 164/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9165 - loss: 0.2161 - val_accuracy: 0.9429 - val_loss: 0.1912
# Epoch 165/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9158 - loss: 0.2031 - val_accuracy: 0.9310 - val_loss: 0.1977
# Epoch 166/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9231 - loss: 0.2043 - val_accuracy: 0.9048 - val_loss: 0.2251
# Epoch 167/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9166 - loss: 0.2179 - val_accuracy: 0.9405 - val_loss: 0.1897
# Epoch 168/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9276 - loss: 0.1930 - val_accuracy: 0.9310 - val_loss: 0.1901
# Epoch 169/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9270 - loss: 0.1965 - val_accuracy: 0.9000 - val_loss: 0.2353
# Epoch 170/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9141 - loss: 0.2114 - val_accuracy: 0.9381 - val_loss: 0.1886
# Epoch 171/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9216 - loss: 0.1963 - val_accuracy: 0.9405 - val_loss: 0.1885
# Epoch 172/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9216 - loss: 0.1963 - val_accuracy: 0.9405 - val_loss: 0.1880
# Epoch 173/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9271 - loss: 0.1960 - val_accuracy: 0.9405 - val_loss: 0.1877
# Epoch 174/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9280 - loss: 0.1926 - val_accuracy: 0.8905 - val_loss: 0.2404
# Epoch 175/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9284 - loss: 0.1890 - val_accuracy: 0.9381 - val_loss: 0.1867
# Epoch 176/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9233 - loss: 0.1988 - val_accuracy: 0.9214 - val_loss: 0.2028
# Epoch 177/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9151 - loss: 0.2156 - val_accuracy: 0.9333 - val_loss: 0.1869
# Epoch 178/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9244 - loss: 0.2070 - val_accuracy: 0.9381 - val_loss: 0.1859
# Epoch 179/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9225 - loss: 0.1961 - val_accuracy: 0.9381 - val_loss: 0.1855
# Epoch 180/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9349 - loss: 0.1933 - val_accuracy: 0.9143 - val_loss: 0.2091
# Epoch 181/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9136 - loss: 0.2039 - val_accuracy: 0.9071 - val_loss: 0.2277
# Epoch 182/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9137 - loss: 0.2124 - val_accuracy: 0.9333 - val_loss: 0.1856
# Epoch 183/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9257 - loss: 0.1826 - val_accuracy: 0.9381 - val_loss: 0.1843
# Epoch 184/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9306 - loss: 0.1888 - val_accuracy: 0.9357 - val_loss: 0.1895
# Epoch 185/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9292 - loss: 0.1903 - val_accuracy: 0.9262 - val_loss: 0.1882
# Epoch 186/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9320 - loss: 0.1809 - val_accuracy: 0.9381 - val_loss: 0.1844
# Epoch 187/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9228 - loss: 0.1981 - val_accuracy: 0.9333 - val_loss: 0.1841
# Epoch 188/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9352 - loss: 0.1809 - val_accuracy: 0.9405 - val_loss: 0.1830
# Epoch 189/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9309 - loss: 0.1742 - val_accuracy: 0.9357 - val_loss: 0.1864
# Epoch 190/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9181 - loss: 0.1935 - val_accuracy: 0.9143 - val_loss: 0.1994
# Epoch 191/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9153 - loss: 0.1976 - val_accuracy: 0.8643 - val_loss: 0.2869
# Epoch 192/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9148 - loss: 0.2212 - val_accuracy: 0.9048 - val_loss: 0.2161
# Epoch 193/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9280 - loss: 0.1783 - val_accuracy: 0.9381 - val_loss: 0.1823
# Epoch 194/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9364 - loss: 0.1759 - val_accuracy: 0.9214 - val_loss: 0.1957
# Epoch 195/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9244 - loss: 0.2013 - val_accuracy: 0.9381 - val_loss: 0.1894
# Epoch 196/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9333 - loss: 0.1817 - val_accuracy: 0.9333 - val_loss: 0.1818
# Epoch 197/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9282 - loss: 0.1893 - val_accuracy: 0.9143 - val_loss: 0.2066
# Epoch 198/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9218 - loss: 0.1797 - val_accuracy: 0.8857 - val_loss: 0.2507
# Epoch 199/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9224 - loss: 0.1991 - val_accuracy: 0.9286 - val_loss: 0.1842
# Epoch 200/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9259 - loss: 0.1873 - val_accuracy: 0.9381 - val_loss: 0.1796
# Final training accuracy: 0.9297618865966797
# Final validation accuracy: 0.938095211982727

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
def predict_labels(model, X):
    proba = model.predict(X, verbose=0)
    return (proba > 0.5).astype(int).ravel()

y_test_pred = predict_labels(model, X_test)

acc_val = accuracy_score(y_test, y_test_pred)
print(f"Validation accuracy: {acc_val:.3f}")

cm = confusion_matrix(y_test, y_test_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title("Confusion matrix — validation set")
plt.show()
# Out:
# Validation accuracy: 0.911

# %%
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    accuracy_score, precision_score, recall_score, f1_score,
    roc_curve, roc_auc_score
)

fpr, tpr, roc_thresholds = roc_curve(y_test, y_test_pred)
auc = roc_auc_score(y_test, y_test_pred)

plt.plot(fpr, tpr, label=f"ROC curve (AUC = {auc:.3f})")
plt.plot([0, 1], [0, 1], "--", label="Random classifier")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC curve")
plt.legend()
plt.show()

print("AUC:", auc)
# Out:
# AUC: 0.9111111111111111

# %% [markdown]
# ## 2. Compute SHAP values
# For tree-based models, we can use **TreeExplainer**, which is very fast.
#
# For classification, SHAP returns contributions per class. Here we explain class **1**.

# %%
#Format fixing
X_train_np = np.asarray(X_train, dtype=np.float32)
X_test_np  = np.asarray(X_test, dtype=np.float32)

print("X_train_np:", X_train_np.shape)
print("X_test_np:", X_test_np.shape)

assert X_train_np.ndim == 2 and X_train_np.shape[1] == 50
assert X_test_np.ndim == 2 and X_test_np.shape[1] == 50
# Out:
# X_train_np: (1680, 50)
# X_test_np: (900, 50)

# %% [markdown]
# # Global interpretability
# We can summarize the model behavior over many samples.
#
# ### SHAP summary plot
# - Each point is a sample
# - Color encodes feature value
# - Horizontal axis is SHAP value (impact on prediction)

# %%
#Select a small background set (important!)
#Use e.g. 50-200 examples (randomly) from training data
background = X_train_np[np.random.choice(X_train_np.shape[0], 100, replace=False)]
X_explain = X_test_np[:50]
#explain: small batch first
X_explain = np.asarray(X_explain).reshape(X_explain.shape[0], 50)

explainer = shap.GradientExplainer(model, background)
shap_values = explainer.shap_values(X_explain)

#For binary classification, shap_values can be a list with one element
sv = shap_values[0] if isinstance(shap_values, list) else shap_values
print("sv shape:", sv.shape)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor
# Received: inputs=['Tensor(shape=(50, 50))']
#   warnings.warn(msg)
# sv shape: (50, 50, 1)

# %%
base = model.predict(background).mean()
print("baseline =", base)
print("min pred =", model.predict(background, verbose=0).min())
print("max pred =", model.predict(background, verbose=0).max())
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# baseline = 0.5029022
# min pred = 0.00035896563
# max pred = 0.9996101

# %%
feature_names = [f"Cl{i:02d}" for i in range(50)]
sv2 = np.squeeze(sv, axis=-1)   #(50, 50, 1) -> (50, 50)
print("sv2 shape:", sv2.shape)

shap.summary_plot(sv2, X_explain, feature_names=feature_names)
# Out:
# sv2 shape: (50, 50)
# /tmp/ipython-input-3628174948.py:5: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(sv2, X_explain, feature_names=feature_names)

# %%
shap.summary_plot(
    sv2,
    X_explain,
    feature_names=feature_names,
    sort=False,
    max_display=50
)
# Out:
# /tmp/ipython-input-3440574566.py:1: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(

# %%
shap.summary_plot(
    sv2,
    X_explain,
    feature_names=feature_names,
    plot_type="bar",
    sort=False
)
# Out:
# /tmp/ipython-input-656204282.py:1: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(

# %%
shap.dependence_plot("Cl07", sv2, X_explain,
                     feature_names=feature_names,
                     interaction_index="Cl12")

# %% [markdown]
# # your turn!

# %% [markdown]
# dataset

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

rng = np.random.default_rng(0)
tf.random.set_seed(0)

plt.rcParams["figure.figsize"] = (6, 4)
plt.rcParams["axes.grid"] = True

# k grid (log-spaced)
k = np.logspace(-3, 0, 200)  # from 1e-3 to 1

def pk_baseline(k, A=1.0, ns=0.96, k_damp=0.4):
    """
    Toy ΛCDM-like matter power spectrum:
    - power-law tilt with ns
    - exponential small-scale damping
    """
    pk = A * (k ** ns) * np.exp(-(k / k_damp)**2)
    return pk

def pk_feature_model(k, A=1.0, ns=0.96, k_damp=0.4,
                     amp=0.2, k0=0.1, width=0.05, freq=70):
    """
    Toy "feature model": baseline P(k) times a localized oscillatory feature.
    """
    pk0 = pk_baseline(k, A=A, ns=ns, k_damp=k_damp)
    bump = np.exp(-0.5*((k - k0)/width)**2) * np.sin(freq*(k-k0))
    return pk0 * (1.0 + amp*bump)

pk0 = pk_baseline(k)
pk1 = pk_feature_model(k)

plt.plot(k, pk0, label="Class 0: baseline ΛCDM-like")
plt.plot(k, pk1, label="Class 1: feature model")
plt.xscale("log")
plt.yscale("log")
plt.xlabel("k [arb.]")
plt.ylabel("P(k) [arb.]")
plt.title("One example spectrum from each class")
plt.legend()
plt.show()

def generate_dataset(N=3000, noise_frac=0.05):
    X, y = [], []

    for i in range(N):
        # small baseline parameter variations
        A = rng.uniform(0.9, 1.1)
        ns = rng.uniform(0.92, 1.0)
        k_damp = rng.uniform(0.3, 0.6)

        if rng.random() < 0.5:
            pk = pk_baseline(k, A=A, ns=ns, k_damp=k_damp)
            label = 0
        else:
            amp = rng.uniform(0.15, 0.3)
            k0 = rng.uniform(0.06, 0.18)
            width = rng.uniform(0.02, 0.06)
            freq = rng.uniform(40, 90)

            pk = pk_feature_model(k, A=A, ns=ns, k_damp=k_damp,
                                  amp=amp, k0=k0, width=width, freq=freq)
            label = 1

        # multiplicative noise
        pk_obs = pk * (1.0 + rng.normal(0.0, noise_frac, size=pk.size))

        # log transform to compress dynamic range
        X.append(np.log(pk_obs + 1e-12))
        y.append(label)

    return np.array(X), np.array(y)

X, y = generate_dataset(N=3000, noise_frac=0.05)
print("X shape:", X.shape)
print("Class counts:", np.unique(y, return_counts=True))
# Out:
# X shape: (3000, 200)
# Class counts: (array([0, 1]), array([1504, 1496]))

# %% [markdown]
# Lime

# %%
# !pip install lime
# Out:
# Collecting lime
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from lime) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from lime) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from lime) (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from lime) (4.67.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.12/dist-packages (from lime) (1.6.1)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.12/dist-packages (from lime) (0.25.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime) (3.6.1)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime) (2025.12.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.12->lime) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.18->lime) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.18->lime) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->lime) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->lime) (1.17.0)
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py) ... done
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283834 sha256=f476febfdea1c3d578d9ae3ab733df621bd4b0d226c27ea4b9139b62de15ab8c
#   Stored in directory: /root/.cache/pip/wheels/e7/5d/0e/4b4fff9a47468fed5633211fb3b76d1db43fe806a17fb7486a
# Successfully built lime
# Installing collected packages: lime
# Successfully installed lime-0.2.0.1

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=45
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=45
)

X_train.shape, X_val.shape
# Out:
# ((1680, 200), (420, 200))

# %%
import tensorflow as tf
tf.keras.backend.clear_session()  #Clear previous models from memory

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

input_dim = X_train.shape[1]

def make_cmb_classifier():
    model = Sequential([
        Dense(64, activation="relu", input_shape=(input_dim,)),
        Dense(1, activation="sigmoid")  #binary classification
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    return model

model = make_cmb_classifier()
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │        12,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,929 (50.50 KB)
#  Trainable params: 12,929 (50.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 200
batch_size = 32

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=epochs,
    batch_size=batch_size,
    verbose=1
)

print("Final training accuracy:", history.history["accuracy"][-1])
print("Final validation accuracy:", history.history["val_accuracy"][-1])
# Out:
# Epoch 1/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4957 - loss: 0.8870 - val_accuracy: 0.5429 - val_loss: 0.6874
# Epoch 2/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5013 - loss: 0.7494 - val_accuracy: 0.4905 - val_loss: 0.6970
# Epoch 3/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5088 - loss: 0.7498 - val_accuracy: 0.4905 - val_loss: 0.7034
# Epoch 4/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5075 - loss: 0.7495 - val_accuracy: 0.4905 - val_loss: 0.6979
# Epoch 5/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5083 - loss: 0.7477 - val_accuracy: 0.5000 - val_loss: 0.6896
# Epoch 6/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5035 - loss: 0.7446 - val_accuracy: 0.5548 - val_loss: 0.6872
# Epoch 7/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5068 - loss: 0.7410 - val_accuracy: 0.5667 - val_loss: 0.6866
# Epoch 8/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4988 - loss: 0.7373 - val_accuracy: 0.5619 - val_loss: 0.6867
# Epoch 9/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5013 - loss: 0.7349 - val_accuracy: 0.5381 - val_loss: 0.6873
# Epoch 10/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5084 - loss: 0.7322 - val_accuracy: 0.5310 - val_loss: 0.6890
# Epoch 11/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5104 - loss: 0.7299 - val_accuracy: 0.5190 - val_loss: 0.6890
# Epoch 12/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5090 - loss: 0.7276 - val_accuracy: 0.5143 - val_loss: 0.6917
# Epoch 13/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5097 - loss: 0.7251 - val_accuracy: 0.5143 - val_loss: 0.6908
# Epoch 14/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5122 - loss: 0.7226 - val_accuracy: 0.5143 - val_loss: 0.6916
# Epoch 15/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5159 - loss: 0.7205 - val_accuracy: 0.5119 - val_loss: 0.6926
# Epoch 16/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5146 - loss: 0.7185 - val_accuracy: 0.5095 - val_loss: 0.6937
# Epoch 17/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5143 - loss: 0.7168 - val_accuracy: 0.5095 - val_loss: 0.6976
# Epoch 18/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5163 - loss: 0.7146 - val_accuracy: 0.5095 - val_loss: 0.6946
# Epoch 19/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5131 - loss: 0.7134 - val_accuracy: 0.5095 - val_loss: 0.6970
# Epoch 20/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5211 - loss: 0.7117 - val_accuracy: 0.5095 - val_loss: 0.6936
# Epoch 21/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5189 - loss: 0.7105 - val_accuracy: 0.5095 - val_loss: 0.6939
# Epoch 22/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5244 - loss: 0.7086 - val_accuracy: 0.5095 - val_loss: 0.6954
# Epoch 23/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5292 - loss: 0.7071 - val_accuracy: 0.5095 - val_loss: 0.6956
# Epoch 24/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5339 - loss: 0.7058 - val_accuracy: 0.5095 - val_loss: 0.6957
# Epoch 25/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5387 - loss: 0.7046 - val_accuracy: 0.5095 - val_loss: 0.6966
# Epoch 26/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5401 - loss: 0.7032 - val_accuracy: 0.5095 - val_loss: 0.6993
# Epoch 27/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5376 - loss: 0.7022 - val_accuracy: 0.5095 - val_loss: 0.6952
# Epoch 28/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5353 - loss: 0.7019 - val_accuracy: 0.5095 - val_loss: 0.6973
# Epoch 29/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5378 - loss: 0.6995 - val_accuracy: 0.5095 - val_loss: 0.6979
# Epoch 30/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5402 - loss: 0.6983 - val_accuracy: 0.5095 - val_loss: 0.6970
# Epoch 31/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5395 - loss: 0.6975 - val_accuracy: 0.5095 - val_loss: 0.6971
# Epoch 32/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5437 - loss: 0.6964 - val_accuracy: 0.5119 - val_loss: 0.6969
# Epoch 33/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5372 - loss: 0.6956 - val_accuracy: 0.5119 - val_loss: 0.6970
# Epoch 34/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5401 - loss: 0.6949 - val_accuracy: 0.5119 - val_loss: 0.6949
# Epoch 35/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5388 - loss: 0.6945 - val_accuracy: 0.5119 - val_loss: 0.6962
# Epoch 36/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5435 - loss: 0.6932 - val_accuracy: 0.5119 - val_loss: 0.6951
# Epoch 37/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5422 - loss: 0.6927 - val_accuracy: 0.5119 - val_loss: 0.6958
# Epoch 38/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5427 - loss: 0.6916 - val_accuracy: 0.5119 - val_loss: 0.6945
# Epoch 39/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5480 - loss: 0.6911 - val_accuracy: 0.5119 - val_loss: 0.6973
# Epoch 40/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5532 - loss: 0.6890 - val_accuracy: 0.5143 - val_loss: 0.6941
# Epoch 41/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5502 - loss: 0.6885 - val_accuracy: 0.5143 - val_loss: 0.6947
# Epoch 42/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5487 - loss: 0.6878 - val_accuracy: 0.5143 - val_loss: 0.6928
# Epoch 43/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5486 - loss: 0.6875 - val_accuracy: 0.5143 - val_loss: 0.6937
# Epoch 44/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5501 - loss: 0.6868 - val_accuracy: 0.5143 - val_loss: 0.6938
# Epoch 45/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5492 - loss: 0.6863 - val_accuracy: 0.5143 - val_loss: 0.6924
# Epoch 46/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5512 - loss: 0.6860 - val_accuracy: 0.5143 - val_loss: 0.6922
# Epoch 47/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5514 - loss: 0.6855 - val_accuracy: 0.5143 - val_loss: 0.6924
# Epoch 48/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5549 - loss: 0.6851 - val_accuracy: 0.5143 - val_loss: 0.6915
# Epoch 49/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5522 - loss: 0.6846 - val_accuracy: 0.5190 - val_loss: 0.6906
# Epoch 50/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5525 - loss: 0.6839 - val_accuracy: 0.5143 - val_loss: 0.6939
# Epoch 51/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5503 - loss: 0.6839 - val_accuracy: 0.5167 - val_loss: 0.6937
# Epoch 52/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5547 - loss: 0.6835 - val_accuracy: 0.5190 - val_loss: 0.6926
# Epoch 53/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5508 - loss: 0.6827 - val_accuracy: 0.5214 - val_loss: 0.6906
# Epoch 54/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5534 - loss: 0.6825 - val_accuracy: 0.5214 - val_loss: 0.6912
# Epoch 55/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5541 - loss: 0.6821 - val_accuracy: 0.5167 - val_loss: 0.6918
# Epoch 56/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5535 - loss: 0.6816 - val_accuracy: 0.5214 - val_loss: 0.6899
# Epoch 57/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5549 - loss: 0.6814 - val_accuracy: 0.5214 - val_loss: 0.6891
# Epoch 58/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5557 - loss: 0.6810 - val_accuracy: 0.5238 - val_loss: 0.6891
# Epoch 59/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5558 - loss: 0.6802 - val_accuracy: 0.5238 - val_loss: 0.6908
# Epoch 60/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5508 - loss: 0.6803 - val_accuracy: 0.5238 - val_loss: 0.6884
# Epoch 61/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5473 - loss: 0.6792 - val_accuracy: 0.5214 - val_loss: 0.6907
# Epoch 62/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5490 - loss: 0.6791 - val_accuracy: 0.5167 - val_loss: 0.6926
# Epoch 63/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5460 - loss: 0.6791 - val_accuracy: 0.5214 - val_loss: 0.6894
# Epoch 64/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5453 - loss: 0.6785 - val_accuracy: 0.5167 - val_loss: 0.6894
# Epoch 65/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5432 - loss: 0.6792 - val_accuracy: 0.5238 - val_loss: 0.6833
# Epoch 66/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5503 - loss: 0.6771 - val_accuracy: 0.5286 - val_loss: 0.6819
# Epoch 67/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5510 - loss: 0.6765 - val_accuracy: 0.5238 - val_loss: 0.6848
# Epoch 68/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5491 - loss: 0.6770 - val_accuracy: 0.5286 - val_loss: 0.6828
# Epoch 69/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5561 - loss: 0.6765 - val_accuracy: 0.5238 - val_loss: 0.6851
# Epoch 70/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5514 - loss: 0.6770 - val_accuracy: 0.5333 - val_loss: 0.6806
# Epoch 71/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5611 - loss: 0.6756 - val_accuracy: 0.5238 - val_loss: 0.6845
# Epoch 72/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5546 - loss: 0.6760 - val_accuracy: 0.5238 - val_loss: 0.6835
# Epoch 73/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5548 - loss: 0.6756 - val_accuracy: 0.5238 - val_loss: 0.6837
# Epoch 74/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5559 - loss: 0.6753 - val_accuracy: 0.5238 - val_loss: 0.6835
# Epoch 75/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5500 - loss: 0.6756 - val_accuracy: 0.5333 - val_loss: 0.6801
# Epoch 76/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5587 - loss: 0.6743 - val_accuracy: 0.5262 - val_loss: 0.6827
# Epoch 77/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5557 - loss: 0.6745 - val_accuracy: 0.5286 - val_loss: 0.6817
# Epoch 78/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5564 - loss: 0.6737 - val_accuracy: 0.5262 - val_loss: 0.6834
# Epoch 79/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5579 - loss: 0.6740 - val_accuracy: 0.5262 - val_loss: 0.6823
# Epoch 80/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5583 - loss: 0.6735 - val_accuracy: 0.5262 - val_loss: 0.6821
# Epoch 81/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5575 - loss: 0.6733 - val_accuracy: 0.5286 - val_loss: 0.6815
# Epoch 82/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5596 - loss: 0.6728 - val_accuracy: 0.5286 - val_loss: 0.6794
# Epoch 83/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5596 - loss: 0.6730 - val_accuracy: 0.5310 - val_loss: 0.6793
# Epoch 84/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5595 - loss: 0.6723 - val_accuracy: 0.5333 - val_loss: 0.6793
# Epoch 85/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5615 - loss: 0.6716 - val_accuracy: 0.5262 - val_loss: 0.6816
# Epoch 86/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5590 - loss: 0.6724 - val_accuracy: 0.5262 - val_loss: 0.6788
# Epoch 87/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5679 - loss: 0.6713 - val_accuracy: 0.5333 - val_loss: 0.6769
# Epoch 88/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5635 - loss: 0.6708 - val_accuracy: 0.5286 - val_loss: 0.6804
# Epoch 89/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5627 - loss: 0.6717 - val_accuracy: 0.5333 - val_loss: 0.6778
# Epoch 90/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5632 - loss: 0.6704 - val_accuracy: 0.5286 - val_loss: 0.6783
# Epoch 91/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5678 - loss: 0.6705 - val_accuracy: 0.5357 - val_loss: 0.6772
# Epoch 92/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5689 - loss: 0.6696 - val_accuracy: 0.5286 - val_loss: 0.6805
# Epoch 93/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5654 - loss: 0.6699 - val_accuracy: 0.5333 - val_loss: 0.6774
# Epoch 94/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5660 - loss: 0.6690 - val_accuracy: 0.5286 - val_loss: 0.6803
# Epoch 95/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5681 - loss: 0.6701 - val_accuracy: 0.5333 - val_loss: 0.6772
# Epoch 96/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5649 - loss: 0.6686 - val_accuracy: 0.5286 - val_loss: 0.6796
# Epoch 97/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5690 - loss: 0.6694 - val_accuracy: 0.5333 - val_loss: 0.6776
# Epoch 98/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5716 - loss: 0.6685 - val_accuracy: 0.5381 - val_loss: 0.6769
# Epoch 99/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5704 - loss: 0.6676 - val_accuracy: 0.5286 - val_loss: 0.6799
# Epoch 100/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5747 - loss: 0.6688 - val_accuracy: 0.5333 - val_loss: 0.6767
# Epoch 101/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5734 - loss: 0.6675 - val_accuracy: 0.5381 - val_loss: 0.6759
# Epoch 102/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5750 - loss: 0.6666 - val_accuracy: 0.5333 - val_loss: 0.6787
# Epoch 103/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5739 - loss: 0.6675 - val_accuracy: 0.5333 - val_loss: 0.6799
# Epoch 104/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5740 - loss: 0.6673 - val_accuracy: 0.5333 - val_loss: 0.6771
# Epoch 105/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5715 - loss: 0.6666 - val_accuracy: 0.5333 - val_loss: 0.6782
# Epoch 106/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5706 - loss: 0.6667 - val_accuracy: 0.5286 - val_loss: 0.6790
# Epoch 107/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5670 - loss: 0.6665 - val_accuracy: 0.5333 - val_loss: 0.6798
# Epoch 108/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5771 - loss: 0.6664 - val_accuracy: 0.5405 - val_loss: 0.6737
# Epoch 109/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5755 - loss: 0.6650 - val_accuracy: 0.5381 - val_loss: 0.6739
# Epoch 110/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5802 - loss: 0.6644 - val_accuracy: 0.5405 - val_loss: 0.6733
# Epoch 111/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5763 - loss: 0.6644 - val_accuracy: 0.5357 - val_loss: 0.6763
# Epoch 112/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5744 - loss: 0.6647 - val_accuracy: 0.5381 - val_loss: 0.6749
# Epoch 113/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5819 - loss: 0.6636 - val_accuracy: 0.5405 - val_loss: 0.6727
# Epoch 114/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5808 - loss: 0.6631 - val_accuracy: 0.5357 - val_loss: 0.6783
# Epoch 115/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5822 - loss: 0.6638 - val_accuracy: 0.5381 - val_loss: 0.6762
# Epoch 116/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5811 - loss: 0.6633 - val_accuracy: 0.5381 - val_loss: 0.6752
# Epoch 117/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5786 - loss: 0.6627 - val_accuracy: 0.5357 - val_loss: 0.6765
# Epoch 118/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5831 - loss: 0.6627 - val_accuracy: 0.5381 - val_loss: 0.6746
# Epoch 119/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5820 - loss: 0.6626 - val_accuracy: 0.5405 - val_loss: 0.6743
# Epoch 120/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5773 - loss: 0.6619 - val_accuracy: 0.5381 - val_loss: 0.6765
# Epoch 121/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5862 - loss: 0.6615 - val_accuracy: 0.5357 - val_loss: 0.6778
# Epoch 122/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5806 - loss: 0.6616 - val_accuracy: 0.5381 - val_loss: 0.6749
# Epoch 123/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5814 - loss: 0.6600 - val_accuracy: 0.5357 - val_loss: 0.6773
# Epoch 124/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5893 - loss: 0.6616 - val_accuracy: 0.5381 - val_loss: 0.6758
# Epoch 125/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5849 - loss: 0.6599 - val_accuracy: 0.5381 - val_loss: 0.6744
# Epoch 126/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5896 - loss: 0.6595 - val_accuracy: 0.5452 - val_loss: 0.6707
# Epoch 127/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5943 - loss: 0.6601 - val_accuracy: 0.5405 - val_loss: 0.6754
# Epoch 128/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5821 - loss: 0.6596 - val_accuracy: 0.5429 - val_loss: 0.6740
# Epoch 129/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5927 - loss: 0.6583 - val_accuracy: 0.5405 - val_loss: 0.6731
# Epoch 130/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5914 - loss: 0.6578 - val_accuracy: 0.5405 - val_loss: 0.6736
# Epoch 131/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5878 - loss: 0.6586 - val_accuracy: 0.5405 - val_loss: 0.6713
# Epoch 132/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5914 - loss: 0.6582 - val_accuracy: 0.5405 - val_loss: 0.6719
# Epoch 133/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.5953 - loss: 0.6576 - val_accuracy: 0.5595 - val_loss: 0.6691
# Epoch 134/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6006 - loss: 0.6549 - val_accuracy: 0.5381 - val_loss: 0.6776
# Epoch 135/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5977 - loss: 0.6574 - val_accuracy: 0.5476 - val_loss: 0.6731
# Epoch 136/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5967 - loss: 0.6580 - val_accuracy: 0.5452 - val_loss: 0.6698
# Epoch 137/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5991 - loss: 0.6562 - val_accuracy: 0.5429 - val_loss: 0.6738
# Epoch 138/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5961 - loss: 0.6564 - val_accuracy: 0.5595 - val_loss: 0.6696
# Epoch 139/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6039 - loss: 0.6542 - val_accuracy: 0.5429 - val_loss: 0.6727
# Epoch 140/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6039 - loss: 0.6542 - val_accuracy: 0.5548 - val_loss: 0.6683
# Epoch 141/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6016 - loss: 0.6535 - val_accuracy: 0.5429 - val_loss: 0.6705
# Epoch 142/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.5964 - loss: 0.6532 - val_accuracy: 0.5548 - val_loss: 0.6712
# Epoch 143/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5988 - loss: 0.6551 - val_accuracy: 0.5643 - val_loss: 0.6649
# Epoch 144/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6032 - loss: 0.6528 - val_accuracy: 0.5571 - val_loss: 0.6696
# Epoch 145/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6034 - loss: 0.6534 - val_accuracy: 0.5524 - val_loss: 0.6685
# Epoch 146/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6047 - loss: 0.6509 - val_accuracy: 0.5429 - val_loss: 0.6693
# Epoch 147/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5966 - loss: 0.6514 - val_accuracy: 0.5643 - val_loss: 0.6658
# Epoch 148/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6102 - loss: 0.6512 - val_accuracy: 0.5643 - val_loss: 0.6648
# Epoch 149/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.6083 - loss: 0.6510 - val_accuracy: 0.5643 - val_loss: 0.6652
# Epoch 150/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6092 - loss: 0.6504 - val_accuracy: 0.5714 - val_loss: 0.6625
# Epoch 151/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6113 - loss: 0.6506 - val_accuracy: 0.5429 - val_loss: 0.6721
# Epoch 152/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6072 - loss: 0.6498 - val_accuracy: 0.5714 - val_loss: 0.6639
# Epoch 153/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6143 - loss: 0.6519 - val_accuracy: 0.5643 - val_loss: 0.6660
# Epoch 154/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6072 - loss: 0.6495 - val_accuracy: 0.5643 - val_loss: 0.6646
# Epoch 155/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6110 - loss: 0.6494 - val_accuracy: 0.5643 - val_loss: 0.6648
# Epoch 156/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6106 - loss: 0.6476 - val_accuracy: 0.5667 - val_loss: 0.6609
# Epoch 157/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6131 - loss: 0.6456 - val_accuracy: 0.5810 - val_loss: 0.6604
# Epoch 158/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6109 - loss: 0.6471 - val_accuracy: 0.5643 - val_loss: 0.6657
# Epoch 159/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6094 - loss: 0.6476 - val_accuracy: 0.5929 - val_loss: 0.6575
# Epoch 160/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6172 - loss: 0.6465 - val_accuracy: 0.5643 - val_loss: 0.6649
# Epoch 161/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6171 - loss: 0.6466 - val_accuracy: 0.5643 - val_loss: 0.6624
# Epoch 162/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6121 - loss: 0.6448 - val_accuracy: 0.5714 - val_loss: 0.6605
# Epoch 163/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6154 - loss: 0.6432 - val_accuracy: 0.5786 - val_loss: 0.6630
# Epoch 164/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6174 - loss: 0.6470 - val_accuracy: 0.5738 - val_loss: 0.6607
# Epoch 165/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6146 - loss: 0.6463 - val_accuracy: 0.5738 - val_loss: 0.6605
# Epoch 166/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6143 - loss: 0.6450 - val_accuracy: 0.5690 - val_loss: 0.6612
# Epoch 167/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6171 - loss: 0.6421 - val_accuracy: 0.5690 - val_loss: 0.6626
# Epoch 168/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6173 - loss: 0.6417 - val_accuracy: 0.5762 - val_loss: 0.6582
# Epoch 169/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6139 - loss: 0.6414 - val_accuracy: 0.5905 - val_loss: 0.6554
# Epoch 170/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6224 - loss: 0.6410 - val_accuracy: 0.5786 - val_loss: 0.6581
# Epoch 171/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6234 - loss: 0.6401 - val_accuracy: 0.5762 - val_loss: 0.6594
# Epoch 172/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6183 - loss: 0.6431 - val_accuracy: 0.5881 - val_loss: 0.6555
# Epoch 173/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6227 - loss: 0.6417 - val_accuracy: 0.5905 - val_loss: 0.6544
# Epoch 174/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6275 - loss: 0.6406 - val_accuracy: 0.5881 - val_loss: 0.6550
# Epoch 175/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6244 - loss: 0.6410 - val_accuracy: 0.5881 - val_loss: 0.6554
# Epoch 176/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6275 - loss: 0.6401 - val_accuracy: 0.5786 - val_loss: 0.6571
# Epoch 177/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6196 - loss: 0.6390 - val_accuracy: 0.5905 - val_loss: 0.6534
# Epoch 178/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6293 - loss: 0.6393 - val_accuracy: 0.5905 - val_loss: 0.6554
# Epoch 179/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6208 - loss: 0.6380 - val_accuracy: 0.5952 - val_loss: 0.6531
# Epoch 180/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6284 - loss: 0.6386 - val_accuracy: 0.5952 - val_loss: 0.6519
# Epoch 181/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6301 - loss: 0.6373 - val_accuracy: 0.5857 - val_loss: 0.6560
# Epoch 182/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6292 - loss: 0.6358 - val_accuracy: 0.5929 - val_loss: 0.6520
# Epoch 183/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6261 - loss: 0.6374 - val_accuracy: 0.6071 - val_loss: 0.6485
# Epoch 184/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6278 - loss: 0.6369 - val_accuracy: 0.6024 - val_loss: 0.6501
# Epoch 185/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6329 - loss: 0.6367 - val_accuracy: 0.6024 - val_loss: 0.6502
# Epoch 186/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6308 - loss: 0.6353 - val_accuracy: 0.6119 - val_loss: 0.6484
# Epoch 187/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6354 - loss: 0.6353 - val_accuracy: 0.6000 - val_loss: 0.6506
# Epoch 188/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6308 - loss: 0.6340 - val_accuracy: 0.6024 - val_loss: 0.6495
# Epoch 189/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6304 - loss: 0.6331 - val_accuracy: 0.6024 - val_loss: 0.6506
# Epoch 190/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6319 - loss: 0.6346 - val_accuracy: 0.5857 - val_loss: 0.6574
# Epoch 191/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6358 - loss: 0.6327 - val_accuracy: 0.6429 - val_loss: 0.6448
# Epoch 192/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6357 - loss: 0.6363 - val_accuracy: 0.6310 - val_loss: 0.6468
# Epoch 193/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6349 - loss: 0.6325 - val_accuracy: 0.6167 - val_loss: 0.6497
# Epoch 194/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6384 - loss: 0.6315 - val_accuracy: 0.5976 - val_loss: 0.6524
# Epoch 195/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6413 - loss: 0.6293 - val_accuracy: 0.6119 - val_loss: 0.6471
# Epoch 196/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6332 - loss: 0.6318 - val_accuracy: 0.6143 - val_loss: 0.6464
# Epoch 197/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6372 - loss: 0.6291 - val_accuracy: 0.6167 - val_loss: 0.6463
# Epoch 198/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6332 - loss: 0.6285 - val_accuracy: 0.6095 - val_loss: 0.6473
# Epoch 199/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6375 - loss: 0.6290 - val_accuracy: 0.6381 - val_loss: 0.6420
# Epoch 200/200
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6405 - loss: 0.6286 - val_accuracy: 0.6381 - val_loss: 0.6432
# Final training accuracy: 0.6279761791229248
# Final validation accuracy: 0.6380952596664429

# %%
#metrics

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
def predict_labels(model, X):
    proba = model.predict(X, verbose=0)
    return (proba > 0.5).astype(int).ravel()

y_test_pred = predict_labels(model, X_test)

acc_val = accuracy_score(y_test, y_test_pred)
print(f"Validation accuracy: {acc_val:.3f}")

cm = confusion_matrix(y_test, y_test_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title("Confusion matrix — validation set")
plt.show()
# Out:
# Validation accuracy: 0.611

# %%
def predict_proba_lime(z):
    """
    z: numpy array of shape (n_samples, n_features)
    returns: numpy array of shape (n_samples, 2) with rows summing to 1
    """
    p1 = model.predict(z, verbose=0).reshape(-1)   # P(class=1)
    p1 = np.clip(p1, 1e-6, 1 - 1e-6)               # numerical safety
    p0 = 1.0 - p1
    return np.column_stack([p0, p1])

from lime.lime_tabular import LimeTabularExplainer
from IPython.display import HTML

feature_names = [f"Cl_{i}" for i in range(X_train.shape[1])]

explainer = LimeTabularExplainer(
    training_data=X_train,
    feature_names=feature_names,
    class_names=["LCDM", "Features"],
    mode="classification",
    discretize_continuous=False
)

idx = 10
x0 = X_test[idx]

print("True label:", y_test[idx])
print("Predicted probabilities [LCDM, Features]:", predict_proba_lime(x0.reshape(1, -1))[0])

exp = explainer.explain_instance(
    data_row=x0,
    predict_fn=predict_proba_lime,
    num_features=15,
    num_samples=5000
)

#exp.show_in_notebook(show_table=True)
HTML(exp.as_html())
# Out:
# True label: 0
# Predicted probabilities [LCDM, Features]: [0.57510936 0.4248906 ]
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# /******/ 		// Return the exports of the module
# /******/ 		return module.exports;
# /******/ 	}
# /******/
# /******/
# /******/ 	// expose the modules object (__webpack_modules__)
# /******/ 	__webpack_require__.m = modules;
# /******/
# /******/ 	// expose the module cache
# /******/ 	__webpack_require__.c = installedModules;
# /******/
# /******/ 	// __webpack_public_path__
# /******/ 	__webpack_require__.p = "";
# /******/
# /******/ 	// Load entry module and return exports
# /******/ 	return __webpack_require__(0);
# /******/ })
# /************************************************************************/
# /******/ ([
# /* 0 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	/* WEBPACK VAR INJECTION */(function(global) {'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
# 	exports.PredictedValue = exports.PredictProba = exports.Barchart = exports.Explanation = undefined;
#
# 	var _explanation = __webpack_require__(1);
#
# 	var _explanation2 = _interopRequireDefault(_explanation);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _predict_proba = __webpack_require__(6);
#
# 	var _predict_proba2 = _interopRequireDefault(_predict_proba);
#
# 	var _predicted_value = __webpack_require__(7);
#
# 	var _predicted_value2 = _interopRequireDefault(_predicted_value);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	if (!global._babelPolyfill) {
# 	  __webpack_require__(8);
# 	}
#
# 	__webpack_require__(339);
#
# 	exports.Explanation = _explanation2.default;
# 	exports.Barchart = _bar_chart2.default;
# 	exports.PredictProba = _predict_proba2.default;
# 	exports.PredictedValue = _predicted_value2.default;
# 	//require('style-loader');
# 	/* WEBPACK VAR INJECTION */}.call(exports, (function() { return this; }())))
#
# /***/ }),
# /* 1 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
#
# 	var _slicedToArray = function () { function sliceIterator(arr, i) { var _arr = []; var _n = true; var _d = false; var _e = undefined; try { for (var _i = arr[Symbol.iterator](), _s; !(_n = (_s = _i.next()).done); _n = true) { _arr.push(_s.value); if (i && _arr.length === i) break; } } catch (err) { _d = true; _e = err; } finally { try { if (!_n && _i["return"]) _i["return"](); } finally { if (_d) throw _e; } } return _arr; } return function (arr, i) { if (Array.isArray(arr)) { return arr; } else if (Symbol.iterator in Object(arr)) { return sliceIterator(arr, i); } else { throw new TypeError("Invalid attempt to destructure non-iterable instance"); } }; }();
#
# 	var _d2 = __webpack_require__(2);
#
# 	var _d3 = _interopRequireDefault(_d2);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _lodash = __webpack_require__(4);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	function _classCallCheck(instance, Constructor) { if (!(instance instanceof Constructor)) { throw new TypeError("Cannot call a class as a function"); } }
#
# 	var Explanation = function () {
# 	  function Explanation(class_names) {
# 	    _classCallCheck(this, Explanation);
#
# 	    this.names = class_names;
# 	    if (class_names.length < 10) {
# 	      this.colors = _d3.default.scale.category10().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category10().domain((0, _lodash.range)(this.names.length));
# 	    } else {
# 	      this.colors = _d3.default.scale.category20().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category20().domain((0, _lodash.range)(this.names.length));
# 	    }
# 	  }
# 	  // exp: [(feature-name, weight), ...]
# 	  // label: int
# 	  // div: d3 selection
#
#
# 	  Explanation.prototype.show = function show(exp, label, div) {
# 	    var svg = div.append('svg').style('width', '100%');
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    var names = ['NOT ' + this.names[label], this.names[label]];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	      names = this.names;
# 	    }
# 	    var plot = new _bar_chart2.default(svg, exp, true, names, colors, true, 10);
# 	    svg.style('height', plot.svg_height + 'px');
# 	  };
# 	  // exp has all ocurrences of words, with start index and weight:
# 	  // exp = [('word', 132, -0.13), ('word3', 111, 1.3)
#
#
# 	  Explanation.prototype.show_raw_text = function show_raw_text(exp, label, raw, div) {
# 	    var opacity = arguments.length > 4 && arguments[4] !== undefined ? arguments[4] : true;
#
# 	    //let colors=['#5F9EA0', this.colors(this.exp['class'])];
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var word_lists = [[], []];
# 	    var max_weight = -1;
# 	    var _iteratorNormalCompletion = true;
# 	    var _didIteratorError = false;
# 	    var _iteratorError = undefined;
#
# 	    try {
# 	      for (var _iterator = exp[Symbol.iterator](), _step; !(_iteratorNormalCompletion = (_step = _iterator.next()).done); _iteratorNormalCompletion = true) {
# 	        var _step$value = _slicedToArray(_step.value, 3),
# 	            word = _step$value[0],
# 	            start = _step$value[1],
# 	            weight = _step$value[2];
#
# 	        if (weight > 0) {
# 	          word_lists[1].push([start, start + word.length, weight]);
# 	        } else {
# 	          word_lists[0].push([start, start + word.length, -weight]);
# 	        }
# 	        max_weight = Math.max(max_weight, Math.abs(weight));
# 	      }
# 	    } catch (err) {
# 	      _didIteratorError = true;
# 	      _iteratorError = err;
# 	    } finally {
# 	      try {
# 	        if (!_iteratorNormalCompletion && _iterator.return) {
# 	          _iterator.return();
# 	        }
# 	      } finally {
# 	        if (_didIteratorError) {
# 	          throw _iteratorError;
# 	        }
# 	      }
# 	    }
#
# 	    if (!opacity) {
# 	      max_weight = 0;
# 	    }
# 	    this.display_raw_text(div, raw, word_lists, colors, max_weight, true);
# 	  };
# 	  // exp is list of (feature_name, value, weight)
#
#
# 	  Explanation.prototype.show_raw_tabular = function show_raw_tabular(exp, label, div) {
# 	    div.classed('lime', true).classed('table_div', true);
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var table = div.append('table');
# 	    var thead = table.append('tr');
# 	    thead.append('td').text('Feature');
# 	    thead.append('td').text('Value');
# 	    thead.style('color', 'black').style('font-size', '20px');
# 	    var _iteratorNormalCompletion2 = true;
# 	    var _didIteratorError2 = false;
# 	    var _iteratorError2 = undefined;
#
# 	    try {
# 	      for (var _iterator2 = exp[Symbol.iterator](), _step2; !(_iteratorNormalCompletion2 = (_step2 = _iterator2.next()).done); _iteratorNormalCompletion2 = true) {
# 	        var _step2$value = _slicedToArray(_step2.value, 3),
# 	            fname = _step2$value[0],
# 	            value = _step2$value[1],
# 	            weight = _s

# %% [markdown]
# Shap!

# %%
#Format fixing
X_train_np = np.asarray(X_train, dtype=np.float32)
X_test_np  = np.asarray(X_test, dtype=np.float32)

print("X_train_np:", X_train_np.shape)
print("X_test_np:", X_test_np.shape)

assert X_train_np.ndim == 2 and X_train_np.shape[1] == 50
assert X_test_np.ndim == 2 and X_test_np.shape[1] == 50
